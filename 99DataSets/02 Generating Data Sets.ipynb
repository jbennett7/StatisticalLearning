# %% [markdown]
# # Generating Data Sets

# %%
set.seed(1)
n <- 45
xlim <- c((-pi+1.3),(pi-.3))
x <- seq(xlim[1],xlim[2], length.out=n)
y <- jitter(sin(x),amount=.4)
y.known <- sin(x)
plot(x,y)
lines(x,y.known)
# Out:
# plot without title
