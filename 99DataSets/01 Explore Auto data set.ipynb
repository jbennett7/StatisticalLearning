# %% [markdown]
# # Exploring the Auto data set

# %%
Auto <- read.table("Auto.data", header = T, na.strings = "?", stringsAsFactors = T)
dim(Auto)
names(Auto)
Auto <- na.omit(Auto)
dim(Auto)
attach(Auto)
# Out:
# [1] 397   9
# [1] "mpg"          "cylinders"    "displacement" "horsepower"   "weight"
# [6] "acceleration" "year"         "origin"       "name"
# [1] 392   9

# %%
plot(cylinders, mpg)
# Out:
# plot without title

# %%
cylinders <- as.factor(cylinders)
plot(cylinders, mpg)
# Out:
# plot without title

# %%
pairs(Auto)
# Out:
# plot without title
