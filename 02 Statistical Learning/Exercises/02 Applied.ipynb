# %% [markdown]
# # Applied

# %% [markdown]
# __8.__ This exercise relates to the `College` data set, which can be found in the file `College.csv` on the book website. It contains a number of variables for 777 different universities and colleges in the US. The variables are:
# * `Private`: Public/private indicator
# * `Apps`: Number of applications received
# * `Accept`: Number of applicants accepted
# * `Enroll`: Number of new students enrolled
# * `Top10perc`: New students from top 10% of high school class
# * `Top25perc`: New students from top 25% of high school class
# * `F.Undergrad`: Number of full-time undergraduates
# * `P.Undergrad`: Number of part-time undergraduates
# * `Outstate`: Out-of-state tuition
# * `Room.Board`: Room and board costs
# * `Books`: Estimated book costs
# * `Personal`: Estimated personal spending
# * `PhD`: Percent of faculty with Ph.D.'s
# * `Terminal`: Percent of faculty with terminal degree
# * `S.F.Ratio`: Student/faculty ratio
# * `perc.alumni`: Percent of alumni who donate
# * `Expend`: Instructional expenditure per student
# * `Grad.Rate`: Graduation rate
#
# Before reading the data into `R`, it can be viewed in Excel or a text editor.

# %% [markdown]
# (a) Use the `read.csv()` function to read the data into `R`. Call the loaded data `college`. Make sure that you have the directory set to the correct location for the data.

# %%
college <- read.csv("../../99DataSets/College.csv", stringsAsFactors=T)

# %% [markdown]
# (b) Look at the data using the `View()` function. You should notice that the first column is just th ename of each university. We don't really want `R` to treat this as data. However, it may be handy to have these names for later.

# %%
rownames(college) <- college[,1]
View(college)
# Out:
#                                         X
# Abilene Christian University            Abilene Christian University
# Adelphi University                      Adelphi University
# Adrian College                          Adrian College
# Agnes Scott College                     Agnes Scott College
# Alaska Pacific University               Alaska Pacific University
# Albertson College                       Albertson College
# Albertus Magnus College                 Albertus Magnus College
# Albion College                          Albion College
# Albright College                        Albright College
# Alderson-Broaddus College               Alderson-Broaddus College
# Alfred University                       Alfred University
# Allegheny College                       Allegheny College
# Allentown Coll. of St. Francis de Sales Allentown Coll. of St. Francis de Sales
# Alma College                            Alma College
# Alverno College                         Alverno College
# ...

# %% [markdown]
# You should see that there is now a `row.names` column with the name of each university recorded. This means that `R` has given each row a name corresponding to the appropriate university. `R` will not try to perform calculations on the row names. However, we still need to eliminate the first column in the data where the names are stored.

# %%
college <- college[,-1]
View(college)
# Out:
#                                         Private Apps  Accept Enroll Top10perc
# Abilene Christian University            Yes      1660  1232   721   23
# Adelphi University                      Yes      2186  1924   512   16
# Adrian College                          Yes      1428  1097   336   22
# Agnes Scott College                     Yes       417   349   137   60
# Alaska Pacific University               Yes       193   146    55   16
# Albertson College                       Yes       587   479   158   38
# Albertus Magnus College                 Yes       353   340   103   17
# Albion College                          Yes      1899  1720   489   37
# Albright College                        Yes      1038   839   227   30
# Alderson-Broaddus College               Yes       582   498   172   21
# Alfred University                       Yes      1732  1425   472   37
# Allegheny College                       Yes      2652  1900   484   44
# ...

# %% [markdown]
# Now you should see that the first data column is `Private`. Note that another column labeled `row.names` now appears before the `Private` column. However, this is not a data column but rather the name that `R` has given each row.

# %% [markdown]
# (c)

# %% [markdown]
# i.  Use the `summary()` function to produce a numerical summary of the variables in the data set.

# %%
summary(college)
# Out:
#  Private        Apps           Accept          Enroll       Top10perc
#  No :212   Min.   :   81   Min.   :   72   Min.   :  35   Min.   : 1.00
#  Yes:565   1st Qu.:  776   1st Qu.:  604   1st Qu.: 242   1st Qu.:15.00
#            Median : 1558   Median : 1110   Median : 434   Median :23.00
#            Mean   : 3002   Mean   : 2019   Mean   : 780   Mean   :27.56
#            3rd Qu.: 3624   3rd Qu.: 2424   3rd Qu.: 902   3rd Qu.:35.00
#            Max.   :48094   Max.   :26330   Max.   :6392   Max.   :96.00
#    Top25perc      F.Undergrad     P.Undergrad         Outstate
#  Min.   :  9.0   Min.   :  139   Min.   :    1.0   Min.   : 2340
#  1st Qu.: 41.0   1st Qu.:  992   1st Qu.:   95.0   1st Qu.: 7320
#  Median : 54.0   Median : 1707   Median :  353.0   Median : 9990
#  Mean   : 55.8   Mean   : 3700   Mean   :  855.3   Mean   :10441
#  3rd Qu.: 69.0   3rd Qu.: 4005   3rd Qu.:  967.0   3rd Qu.:12925
#  Max.   :100.0   Max.   :31643   Max.   :21836.0   Max.   :21700
# ...

# %% [markdown]
# ii. Use the `pairs()` function to produce a scatterplot matrix of the first ten columns or variables of the data. Recall that you can reference the first ten columns of a matrix `A` using `A[,1:10]`.

# %%
pairs(college[,1:10], cex=0.2)
# Out:
# plot without title

# %% [markdown]
# iii. Use the `plot()` function to produce side-by-side boxplots of `Outstate` versus `Private`.

# %%
plot(college$Private, college$Outstate, xlab="Private", ylab="Number of out of state")
# Out:
# plot without title

# %% [markdown]
# iv. Create a new qualitative variable, called `Elite`, by _binning_ the `Top10perc` variable. We are going to divide universities into two groups based on whether or not the proportion of students coming from the top 10% of their high school classes exceeds 50%

# %%
Elite <- rep("No", nrow(college))
Elite[college$Top10perc > 50] <- "Yes"
Elite <- as.factor(Elite)
college <- data.frame(college, Elite)
summary(college)
plot(college$Elite, college$Outstate, xlab="Elite", ylab="Number of out of state")
# Out:
#  Private        Apps           Accept          Enroll       Top10perc
#  No :212   Min.   :   81   Min.   :   72   Min.   :  35   Min.   : 1.00
#  Yes:565   1st Qu.:  776   1st Qu.:  604   1st Qu.: 242   1st Qu.:15.00
#            Median : 1558   Median : 1110   Median : 434   Median :23.00
#            Mean   : 3002   Mean   : 2019   Mean   : 780   Mean   :27.56
#            3rd Qu.: 3624   3rd Qu.: 2424   3rd Qu.: 902   3rd Qu.:35.00
#            Max.   :48094   Max.   :26330   Max.   :6392   Max.   :96.00
#    Top25perc      F.Undergrad     P.Undergrad         Outstate
#  Min.   :  9.0   Min.   :  139   Min.   :    1.0   Min.   : 2340
#  1st Qu.: 41.0   1st Qu.:  992   1st Qu.:   95.0   1st Qu.: 7320
#  Median : 54.0   Median : 1707   Median :  353.0   Median : 9990
#  Mean   : 55.8   Mean   : 3700   Mean   :  855.3   Mean   :10441
#  3rd Qu.: 69.0   3rd Qu.: 4005   3rd Qu.:  967.0   3rd Qu.:12925
#  Max.   :100.0   Max.   :31643   Max.   :21836.0   Max.   :21700
# ...

# %% [markdown]
# v. Use the `hist()` function to produce some histograms with differeing numbers of bins for a few of the quantitiative variables. You may find the command `par(mfrow = c(2,2))` useful: it will divide the print window into four regions so that four plots can be made simultaneously. Modifying the arguments to this function will divide the screen in other ways.

# %%
predictor=college$Grad.Rate
par(mfrow = c(2,2))
hist(predictor, main="Graduation Rate")
hist(predictor, main="Graduation Rate", breaks=5)
hist(predictor, main="Graduation Rate", breaks=20)
hist(predictor, main="Graduation Rate", breaks=30)
# Out:
# Plot with title “Graduation Rate”

# %%
predictor=college$Room.Board
par(mfrow = c(2,2))
hist(predictor, main="Graduation Rate")
hist(predictor, main="Graduation Rate", breaks=5)
hist(predictor, main="Graduation Rate", breaks=20)
hist(predictor, main="Graduation Rate", breaks=30)
# Out:
# Plot with title “Graduation Rate”

# %%
require(ggplot2)
require(dplyr)
require(tidyr)
# Out:
# Loading required package: ggplot2
#
# Loading required package: dplyr
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: tidyr

# %%
college_gathered <- college %>%
  ## remove the variables that are factors
  select(-Private, -Elite) %>% 
  gather()

ggplot(college_gathered, aes(x = value))+
  geom_histogram(stat = "bin")+
  facet_wrap(.~key, scales = "free")+
  theme(axis.text.x = element_text(angle = 90))
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# vi. Continue exploring the data, and provide a brief summary of what you discover.

# %% [markdown]
# The two sets of frequency polygon graphs show the differences between private and non-private institutions and the differences between elite and non-elite institutions.

# %%
options(repr.plot.width=22, repr.plot.height=12)
college_gathered <- college %>%
  ## remove the variables that are factors
  select(-Elite) %>% 
  gather("key", "value", -Private)

ggplot(college_gathered, aes(x = value, colour = Private))+
  geom_density()+
  facet_wrap(.~key, scales = "free")+
  theme(axis.text.x = element_text(angle = 90))
# Out:
# plot without title

# %%
college_gathered <- college %>%
  ## remove the variables that are factors
  select(-Private) %>% 
  gather("key", "value", -Elite)

ggplot(college_gathered, aes(x = value, colour = Elite))+
  geom_density()+
  facet_wrap(.~key, scales = "free")+
  theme(axis.text.x = element_text(angle = 90))
# Out:
# plot without title

# %%
options(repr.plot.width=7, repr.plot.height=7)

# %% [markdown]
# ---

# %% [markdown]
# __9.__ This exercise involves the `Auto` data set studied in the lab. Make sure that the missing values have been removed from the data.

# %%
auto <- read.table("../../99DataSets/Auto.data", header=T, na.strings="?", stringsAsFactors=T)
auto <- na.omit(auto)
auto$year <- as.factor(auto$year)
auto$origin <- as.factor(auto$origin)
head(auto)
# Out:
#   mpg cylinders displacement horsepower weight acceleration year origin
# 1 18  8         307          130        3504   12.0         70   1
# 2 15  8         350          165        3693   11.5         70   1
# 3 18  8         318          150        3436   11.0         70   1
# 4 16  8         304          150        3433   12.0         70   1
# 5 17  8         302          140        3449   10.5         70   1
# 6 15  8         429          198        4341   10.0         70   1
#   name
# 1 chevrolet chevelle malibu
# 2 buick skylark 320
# 3 plymouth satellite
# 4 amc rebel sst
# 5 ford torino
# 6 ford galaxie 500

# %% [markdown]
# (a) Which of the predictors are quantitative predictors, and which are qualitative predictors?

# %%
summary(auto)
# Out:
#       mpg          cylinders      displacement     horsepower        weight
#  Min.   : 9.00   Min.   :3.000   Min.   : 68.0   Min.   : 46.0   Min.   :1613
#  1st Qu.:17.00   1st Qu.:4.000   1st Qu.:105.0   1st Qu.: 75.0   1st Qu.:2225
#  Median :22.75   Median :4.000   Median :151.0   Median : 93.5   Median :2804
#  Mean   :23.45   Mean   :5.472   Mean   :194.4   Mean   :104.5   Mean   :2978
#  3rd Qu.:29.00   3rd Qu.:8.000   3rd Qu.:275.8   3rd Qu.:126.0   3rd Qu.:3615
#  Max.   :46.60   Max.   :8.000   Max.   :455.0   Max.   :230.0   Max.   :5140
#
#   acceleration        year     origin                  name
#  Min.   : 8.00   73     : 40   1:245   amc matador       :  5
#  1st Qu.:13.78   78     : 36   2: 68   ford pinto        :  5
#  Median :15.50   76     : 34   3: 79   toyota corolla    :  5
#  Mean   :15.54   75     : 30           amc gremlin       :  4
#  3rd Qu.:17.02   82     : 30           amc hornet        :  4
# ...

# %%
qualitative <- c('year', 'origin', 'name')
quantitative <- names(auto)[!(names(auto) %in% qualitative)]
cat("Qualitative predictors: ", qualitative, "\n")
cat("Quantitative predictors: ", quantitative, "\n")
# Out:
# Qualitative predictors:  year origin name
# Quantitative predictors:  mpg cylinders displacement horsepower weight acceleration

# %% [markdown]
# (b) What is the _range_ of each quantitative predictor? You can answer this using the `range()` function.

# %%
quant_data <- subset(auto, select = colnames(auto) %in% quantitative)
apply(quant_data, 2, range)
# Out:
#      mpg  cylinders displacement horsepower weight acceleration
# [1,]  9.0 3          68           46        1613    8.0
# [2,] 46.6 8         455          230        5140   24.8

# %% [markdown]
# (c) What is the mean and standard deviation of each quantitative predictor?

# %%
apply(quant_data, 2, mean)
apply(quant_data, 2, sd)
# Out:
#          mpg    cylinders displacement   horsepower       weight acceleration
#    23.445918     5.471939   194.411990   104.469388  2977.584184    15.541327
#          mpg    cylinders displacement   horsepower       weight acceleration
#     7.805007     1.705783   104.644004    38.491160   849.402560     2.758864

# %% [markdown]
# (d) Now remove the 10th through 85th observations. What is the range, mean, and standard deviation of each predictor in the subset of the data that remains?

# %%
sub_quant <- quant_data[-(10:85),]
apply(sub_quant, 2, range)
apply(sub_quant, 2, mean)
apply(sub_quant, 2, sd)
# Out:
#      mpg  cylinders displacement horsepower weight acceleration
# [1,] 11.0 3          68           46        1649    8.5
# [2,] 46.6 8         455          230        4997   24.8
#          mpg    cylinders displacement   horsepower       weight acceleration
#    24.404430     5.373418   187.240506   100.721519  2935.971519    15.726899
#          mpg    cylinders displacement   horsepower       weight acceleration
#     7.867283     1.654179    99.678367    35.708853   811.300208     2.693721

# %% [markdown]
# (e) Using the full data set, investigate the predictors graphically, using scatterplots or other tools of your choice. Create some plots highlighting the relationships among the predictors. Comment on your findings.

# %%
options(repr.plot.width=12, repr.plot.height=12)
pairs(auto)
options(repr.plot.width=7, repr.plot.height=7)
# Out:
# plot without title

# %%
options(repr.plot.width=20, repr.plot.height=12)
## remember gather() akin to melt()
quant_data_gathered <- quant_data %>%
  gather()
## quick histograms
ggplot(quant_data_gathered, aes(x = value))+
  geom_histogram()+
  facet_wrap(.~key, scales = "free")+
  theme(axis.text.x = element_text(angle = 90))
options(repr.plot.width=7, repr.plot.height=7)
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# (f) Suppose that we wish to predict gas mileage (`mpg`) on the basis of the other variables. Do your plots suggest that any of the other variables might be useful in predicting `mpg`? Justify your answer.

# %%
cor(quant_data)
# Out:
#              mpg        cylinders  displacement horsepower weight
# mpg           1.0000000 -0.7776175 -0.8051269   -0.7784268 -0.8322442
# cylinders    -0.7776175  1.0000000  0.9508233    0.8429834  0.8975273
# displacement -0.8051269  0.9508233  1.0000000    0.8972570  0.9329944
# horsepower   -0.7784268  0.8429834  0.8972570    1.0000000  0.8645377
# weight       -0.8322442  0.8975273  0.9329944    0.8645377  1.0000000
# acceleration  0.4233285 -0.5046834 -0.5438005   -0.6891955 -0.4168392
#              acceleration
# mpg           0.4233285
# cylinders    -0.5046834
# displacement -0.5438005
# horsepower   -0.6891955
# weight       -0.4168392
# acceleration  1.0000000

# %% [markdown]
# Corelation above $|\text{predictor}|>.5$: cylinders, displacement, horsepower, weight.

# %%
options(repr.plot.width=15, repr.plot.height=10)
par(mfrow = c(2,2))
plot(auto$displacement, auto$mpg)
plot(auto$weight, auto$mpg)
plot(auto$horsepower, auto$mpg)
plot(auto$weight, auto$mpg)
options(repr.plot.width=7, repr.plot.height=7)
# Out:
# plot without title

# %% [markdown]
# For Qualtitative

# %%
plot(auto$year, auto$mpg, xlab="Year", ylab="MPG")
plot(auto$origin, auto$mpg, xlab="Origin", ylab="MPG")
#plot(auto$name[1:5], auto$mpg[1:5], xlab="Name", ylab="MPG")
# Out:
# plot without title
# plot without title

# %% [markdown]
# ---

# %% [markdown]
# __10.__ This exercise involves the `Boston` housing data set.

# %% [markdown]
# (a) To begin, load in the `Boston` data set. The `Boston` data set is part of the `ISLR2` _library_.

# %%
library(ISLR2)

# %%
Boston
# Out:
#     crim     zn   indus chas nox   rm    age   dis    rad tax ptratio lstat
# 1   0.00632  18.0 2.31  0    0.538 6.575  65.2 4.0900 1   296 15.3     4.98
# 2   0.02731   0.0 7.07  0    0.469 6.421  78.9 4.9671 2   242 17.8     9.14
# 3   0.02729   0.0 7.07  0    0.469 7.185  61.1 4.9671 2   242 17.8     4.03
# 4   0.03237   0.0 2.18  0    0.458 6.998  45.8 6.0622 3   222 18.7     2.94
# 5   0.06905   0.0 2.18  0    0.458 7.147  54.2 6.0622 3   222 18.7     5.33
# 6   0.02985   0.0 2.18  0    0.458 6.430  58.7 6.0622 3   222 18.7     5.21
# 7   0.08829  12.5 7.87  0    0.524 6.012  66.6 5.5605 5   311 15.2    12.43
# 8   0.14455  12.5 7.87  0    0.524 6.172  96.1 5.9505 5   311 15.2    19.15
# 9   0.21124  12.5 7.87  0    0.524 5.631 100.0 6.0821 5   311 15.2    29.93
# 10  0.17004  12.5 7.87  0    0.524 6.004  85.9 6.5921 5   311 15.2    17.10
# 11  0.22489  12.5 7.87  0    0.524 6.377  94.3 6.3467 5   311 15.2    20.45
# ...

# %% [markdown]
# Read about the data set:

# %%
?Boston
# Out:
# Boston                  package:ISLR2                  R Documentation
#
# a
#
# n:
#
#      A data set containing housing values in 506 suburbs of Boston.
#
# e:
#
#      Boston
#
# t:
#
#      A data frame with 506 rows and 13 variables.
#
#      ‘crim’ per capita crime rate by town.
#
#      ‘zn’ proportion of residential land zoned for lots over 25,000
#           sq.ft.
#
#      ‘indus’ proportion of non-retail business acres per town.
#
#      ‘chas’ Charles River dummy variable (= 1 if tract bounds river; 0
#           otherwise).
#
#      ‘nox’ nitrogen oxides concentration (parts per 10 million).
#
#      ‘rm’ average number of rooms per dwelling.
#
#      ‘age’ proportion of owner-occupied units built prior to 1940.
#
#      ‘dis’ weighted mean of distances to five Boston employment
#           centres.
#
#      ‘rad’ index of accessibility to radial highways.
#
#      ‘tax’ full-value property-tax rate per $10,000.
#
#      ‘ptratio’ pupil-teacher ratio by town.
#
# ...

# %% [markdown]
# How many rows are in this data set? How many columns? Wat do the rows and columns represent?

# %%
dim(Boston)
Boston$chas <- as.factor(Boston$chas)
Boston$rad <- as.factor(Boston$rad)
qual <- c('chas', 'rad')
quant <- names(Boston)[!(names(Boston) %in% qual)]
quant_data <- subset(Boston, select = colnames(Boston) %in% quant)
head(Boston)
summary(Boston)
# Out:
# [1] 506  13
#   crim    zn indus chas nox   rm    age  dis    rad tax ptratio lstat medv
# 1 0.00632 18 2.31  0    0.538 6.575 65.2 4.0900 1   296 15.3    4.98  24.0
# 2 0.02731  0 7.07  0    0.469 6.421 78.9 4.9671 2   242 17.8    9.14  21.6
# 3 0.02729  0 7.07  0    0.469 7.185 61.1 4.9671 2   242 17.8    4.03  34.7
# 4 0.03237  0 2.18  0    0.458 6.998 45.8 6.0622 3   222 18.7    2.94  33.4
# 5 0.06905  0 2.18  0    0.458 7.147 54.2 6.0622 3   222 18.7    5.33  36.2
# 6 0.02985  0 2.18  0    0.458 6.430 58.7 6.0622 3   222 18.7    5.21  28.7
#       crim                zn             indus       chas         nox
#  Min.   : 0.00632   Min.   :  0.00   Min.   : 0.46   0:471   Min.   :0.3850
#  1st Qu.: 0.08205   1st Qu.:  0.00   1st Qu.: 5.19   1: 35   1st Qu.:0.4490
#  Median : 0.25651   Median :  0.00   Median : 9.69           Median :0.5380
#  Mean   : 3.61352   Mean   : 11.36   Mean   :11.14           Mean   :0.5547
# ...

# %% [markdown]
# The rows represent the suburbs of Boston. There are 506 suburbs that are represented in this data set. The columns represent the variables that were tabulated. Variables include the crime rate per capita for each suburb, the zoning of the properties in the suburb, etc...

# %% [markdown]
# (b) Make some pairwise scatterplots of the predictors (columns) in this data set. Describe your findings.

# %%
options(repr.plot.width=15, repr.plot.height=15)
pairs(Boston)
options(repr.plot.width=7, repr.plot.height=7)
# Out:
# plot without title

# %% [markdown]
# (c) Are any of the predictors associated with per capita crime rate? If so, explain the relationship.

# %%
plot(Boston$medv,Boston$crim)
# Out:
# plot without title

# %% [markdown]
# (d) Do any of the census tracts of Boston appear to have particularly high crime rates? Tax rates? Pupil-teacher ratios? Comment on the range of each predictor.

# %%
summary(Boston$crim)
which.max(Boston$crim)
boxplot(Boston$crim)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#  0.00632  0.08204  0.25651  3.61352  3.67708 88.97620
# [1] 381
# plot without title

# %%
summary(Boston$tax)
which.max(Boston$tax)
boxplot(Boston$tax)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   187.0   279.0   330.0   408.2   666.0   711.0
# [1] 489
# plot without title

# %%
summary(Boston$ptratio)
which.max(Boston$ptratio)
boxplot(Boston$ptratio)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   12.60   17.40   19.05   18.46   20.20   22.00
# [1] 355
# plot without title

# %% [markdown]
# (e) How many of the census tracts in this data set bound the Charles river?

# %%
sum(Boston$chas == 1)
# Out:
# [1] 35

# %% [markdown]
# (f) What is the median pupil-teacher ratio among the towns in this data set?

# %%
median(Boston$ptratio)
# Out:
# [1] 19.05

# %% [markdown]
# (g) Which census tract of Boston has lowest median value of owner-occupied homes? What are the values of the other predictors for that census tract, and how do those values compare to the overall ranges for those predictors? Comment on your findings.

# %%
which.min(Boston$medv)
# Out:
# [1] 399

# %%
Boston[which.min(Boston$medv),]
# Out:
#     crim    zn indus chas nox   rm    age dis    rad tax ptratio lstat medv
# 399 38.3518 0  18.1  0    0.693 5.453 100 1.4896 24  666 20.2    30.59 5

# %%
options(repr.plot.width=20, repr.plot.height=15)
par(mfrow = c(4,5))
for (p in names(quant_data)){
    vec <- as.vector(Boston[,c(p)])
    boxplot(vec, main=p)
    points(Boston[which.min(Boston$medv),c(p)], col="red", pch=20, cex=2)
}
# Out:
# Plot with title “medv”

# %% [markdown]
# (h) In this data set, how many of the census tracts average more than seven rooms per dwelling? More than eight rooms per dwelling? Comment on the census tracts that average more than eight rooms per dwelling?

# %%
sum(Boston$rm > 7)
sum(Boston$rm > 8)
# Out:
# [1] 64
# [1] 13

# %%
summary(Boston[Boston$rm > 8,])
options(repr.plot.width=20, repr.plot.height=15)
par(mfrow = c(4,5))
for (p in names(quant_data)){
    gt8 <- as.vector(Boston[Boston$rm > 8,c(p)])
    all <- as.vector(Boston[,c(p)])
    boxplot(gt8, all, names=c('rms gt 8', 'all'), main=p)
}
# Out:
#       crim               zn            indus        chas        nox
#  Min.   :0.02009   Min.   : 0.00   Min.   : 2.680   0:11   Min.   :0.4161
#  1st Qu.:0.33147   1st Qu.: 0.00   1st Qu.: 3.970   1: 2   1st Qu.:0.5040
#  Median :0.52014   Median : 0.00   Median : 6.200          Median :0.5070
#  Mean   :0.71879   Mean   :13.62   Mean   : 7.078          Mean   :0.5392
#  3rd Qu.:0.57834   3rd Qu.:20.00   3rd Qu.: 6.200          3rd Qu.:0.6050
#  Max.   :3.47428   Max.   :95.00   Max.   :19.580          Max.   :0.7180
#
#        rm             age             dis             rad         tax
#  Min.   :8.034   Min.   : 8.40   Min.   :1.801   8      :5   Min.   :224.0
#  1st Qu.:8.247   1st Qu.:70.40   1st Qu.:2.288   5      :4   1st Qu.:264.0
#  Median :8.297   Median :78.30   Median :2.894   2      :1   Median :307.0
#  Mean   :8.349   Mean   :71.54   Mean   :3.430   4      :1   Mean   :325.1
#  3rd Qu.:8.398   3rd Qu.:86.50   3rd Qu.:3.652   7      :1   3rd Qu.:307.0
# ...

# %%
options(repr.plot.width=7, repr.plot.height=7)
