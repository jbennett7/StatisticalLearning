# %% [markdown]
# # More Data Generation Classification Data

# %%
set.seed(1)
x <- matrix(rnorm(100 * 2), ncol = 2)
x[1:30,] <- x[1:30,] - 3
x[31:60,] <- x[31:60,] + 3
y <- c(rep(-1,60),rep(1,40))
x[y == 1,] <- x[y == 1,] + 1
plot(x, col = (3 - y))
# Out:
# plot without title
