# %% [markdown]
# # Generating Data Sets

# %% [markdown]
# ## Basics

# %% [markdown]
# The `rnorm()` function generates a vector of random
# normal variables, with first argument `n` the sample size.  Each
# time we call this function, we will get a different answer. Here we
# create two correlated sets of numbers, `x` and `y`, and use
# the `cor()` function to compute the correlation between
# them.

# %%
x <- rnorm(50)
y <- x + rnorm(50, mean = 50, sd = .1)
cor(x, y)
# Out:
# [1] 0.9950335

# %% [markdown]
# By default, `rnorm()` creates standard normal random variables with a mean of $0$ and a standard deviation of $1$. However, the mean and standard deviation can be altered using the `mean` and `sd` arguments,
# as illustrated above. Sometimes we want our code to reproduce the exact same set of random numbers; we can use the `set.seed()` function to do this. The `set.seed()` function takes an (arbitrary) integer argument.

# %%
set.seed(1303)
rnorm(50)
# Out:
#  [1] -1.1439763145  1.3421293656  2.1853904757  0.5363925179  0.0631929665
#  [6]  0.5022344825 -0.0004167247  0.5658198405 -0.5725226890 -1.1102250073
# [11] -0.0486871234 -0.6956562176  0.8289174803  0.2066528551 -0.2356745091
# [16] -0.5563104914 -0.3647543571  0.8623550343 -0.6307715354  0.3136021252
# [21] -0.9314953177  0.8238676185  0.5233707021  0.7069214120  0.4202043256
# [26] -0.2690521547 -1.5103172999 -0.6902124766 -0.1434719524 -1.0135274099
# [31]  1.5732737361  0.0127465055  0.8726470499  0.4220661905 -0.0188157917
# [36]  2.6157489689 -0.6931401748 -0.2663217810 -0.7206364412  1.3677342065
# [41]  0.2640073322  0.6321868074 -1.3306509858  0.0268888182  1.0406363208
# [46]  1.3120237985 -0.0300020767 -0.2500257125  0.0234144857  1.6598706557

# %% [markdown]
# We use `set.seed()` throughout the labs whenever we perform calculations involving random quantities. In general this should allow the user to reproduce our results. However,  as new versions of `R` become available,  small discrepancies may arise between this book and the output from `R`.
#
# The `mean()` and `var()` functions can be used to compute the mean and variance of a vector of numbers. Applying `sqrt()` to the output of `var()` will give the standard deviation. Or we can simply use the
# `sd()` function.

# %%
set.seed(3)
y <- rnorm(100)
mean(y)
var(y)
sqrt(var(y))
sd(y)
# Out:
# [1] 0.01103557
# [1] 0.7328675
# [1] 0.8560768
# [1] 0.8560768

# %% [markdown]
# ## Random data set where the predictor (x) is independent from the response (y)

# %%
set.seed(1)
x <- rnorm(100)
y <- rnorm(100)
cor(x,y)
plot(x, y)
fit <- lm(y ~ x)
lines(x,fit$fit, col="blue")
summary(fit)
# Out:
# [1] -0.0009943199
# Call:
# lm(formula = y ~ x)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.8768 -0.6138 -0.1395  0.5394  2.3462
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.03769    0.09699  -0.389    0.698
# x           -0.00106    0.10773  -0.010    0.992
#
# Residual standard error: 0.9628 on 98 degrees of freedom
# Multiple R-squared:  9.887e-07,	Adjusted R-squared:  -0.0102
# F-statistic: 9.689e-05 on 1 and 98 DF,  p-value: 0.9922
# plot without title

# %% [markdown]
# ## Adding some correlation

# %%
set.seed(1)
x <- rnorm(100)
y <- x + rnorm(100, sd=1.62131)
cor(x, y)
plot(x, y)
fit <- lm(y ~ x)
lines(x,fit$fit, col="blue")
summary(fit)
# Out:
# [1] 0.5000082
# Call:
# lm(formula = y ~ x)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.0429 -0.9951 -0.2262  0.8745  3.8039
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.06111    0.15725  -0.389    0.698
# x            0.99828    0.17466   5.716 1.18e-07 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.561 on 98 degrees of freedom
# Multiple R-squared:   0.25,	Adjusted R-squared:  0.2424
# F-statistic: 32.67 on 1 and 98 DF,  p-value: 1.18e-07
# plot without title

# %%
set.seed(1)
x <- rnorm(100)
y <- x + rnorm(100, sd=1)
cor(x, y)
plot(x, y)
fit <- lm(y ~ x)
lines(x,fit$fit, col="blue")
summary(fit)
# Out:
# [1] 0.6836311
# Call:
# lm(formula = y ~ x)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.8768 -0.6138 -0.1395  0.5394  2.3462
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.03769    0.09699  -0.389    0.698
# x            0.99894    0.10773   9.273 4.58e-15 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.9628 on 98 degrees of freedom
# Multiple R-squared:  0.4674,	Adjusted R-squared:  0.4619
# F-statistic: 85.99 on 1 and 98 DF,  p-value: 4.583e-15
# plot without title

# %%
set.seed(1)
x <- rnorm(100)
y <- x + rnorm(100, sd=.5)
cor(x, y)
plot(x, y)
fit <- lm(y ~ x)
lines(x,fit$fit, col="blue")
summary(fit)
# Out:
# [1] 0.8822902
# Call:
# lm(formula = y ~ x)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.93842 -0.30688 -0.06975  0.26970  1.17309
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.01885    0.04849  -0.389    0.698
# x            0.99947    0.05386  18.556   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.4814 on 98 degrees of freedom
# Multiple R-squared:  0.7784,	Adjusted R-squared:  0.7762
# F-statistic: 344.3 on 1 and 98 DF,  p-value: < 2.2e-16
# plot without title

# %%
set.seed(1)
x <- rnorm(100)
y <- x + rnorm(100, sd=.1)
cor(x,y)
plot(x,y)
fit <- lm(y ~ x)
lines(x,fit$fit, col="blue")
summary(fit)
# Out:
# [1] 0.9943604
# Call:
# lm(formula = y ~ x)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.18768 -0.06138 -0.01395  0.05394  0.23462
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.003769   0.009699  -0.389    0.698
# x            0.999894   0.010773  92.817   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.09628 on 98 degrees of freedom
# Multiple R-squared:  0.9888,	Adjusted R-squared:  0.9886
# F-statistic:  8615 on 1 and 98 DF,  p-value: < 2.2e-16
# plot without title

# %% [markdown]
# ## Non-linear relationships

# %%
set.seed(1)
x <- seq(-pi,pi,by=.1)
y <- sin(x) + rnorm(length(x),sd=1)
plot(x, y)
fit <- lm(y ~ poly(x,4))
lines(x,fit$fit, col="blue")
summary(fit)
# Out:
# Call:
# lm(formula = y ~ poly(x, 4))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.43671 -0.50360  0.03331  0.59428  1.89595
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   0.1510     0.1141   1.324  0.19071
# poly(x, 4)1   4.9335     0.9056   5.448 1.09e-06 ***
# poly(x, 4)2   1.1213     0.9056   1.238  0.22062
# poly(x, 4)3  -2.7561     0.9056  -3.044  0.00351 **
# poly(x, 4)4  -0.5851     0.9056  -0.646  0.52074
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.9056 on 58 degrees of freedom
# Multiple R-squared:  0.4135,	Adjusted R-squared:  0.3731
# F-statistic: 10.22 on 4 and 58 DF,  p-value: 2.472e-06
# plot without title

# %%
set.seed(1)
x <- seq(-pi,pi,by=.1)
y <- sin(x) + rnorm(length(x),sd=0.5)
plot(x, y)
fit <- lm(y ~ poly(x,4) )
lines(x,fit$fit, col="blue")
summary(fit)
# Out:
# Call:
# lm(formula = y ~ poly(x, 4))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.20616 -0.24000  0.02631  0.29352  0.96234
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.07558    0.05789   1.306    0.197
# poly(x, 4)1  4.64233    0.45946  10.104 2.11e-14 ***
# poly(x, 4)2  0.67291    0.45946   1.465    0.148
# poly(x, 4)3 -3.12088    0.45946  -6.793 6.53e-09 ***
# poly(x, 4)4 -0.32477    0.45946  -0.707    0.482
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.4595 on 58 degrees of freedom
# Multiple R-squared:  0.7223,	Adjusted R-squared:  0.7032
# F-statistic: 37.72 on 4 and 58 DF,  p-value: 1.601e-15
# plot without title

# %%
set.seed(1)
x <- seq(-pi,pi,by=.1)
y <- sin(x) + rnorm(length(x),sd=0.2)
plot(x, y)
fit <- lm(y ~ poly(x,4))
lines(x,fit$fit, col="blue")
summary(fit)
# Out:
# Call:
# lm(formula = y ~ poly(x, 4))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.49179 -0.09554  0.02355  0.11805  0.40218
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.03030    0.02489   1.218   0.2283
# poly(x, 4)1  4.46763    0.19752  22.619   <2e-16 ***
# poly(x, 4)2  0.40389    0.19752   2.045   0.0454 *
# poly(x, 4)3 -3.33973    0.19752 -16.908   <2e-16 ***
# poly(x, 4)4 -0.16857    0.19752  -0.853   0.3969
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1975 on 58 degrees of freedom
# Multiple R-squared:  0.9326,	Adjusted R-squared:  0.9279
# F-statistic: 200.6 on 4 and 58 DF,  p-value: < 2.2e-16
# plot without title

# %%
set.seed(1)
x <- seq(-pi,pi,by=.1)
y <- sin(x) + rnorm(length(x),sd=0.1)
plot(x, y)
fit <- lm(y ~ poly(x,4) )
lines(x,fit$fit, col="blue")
summary(fit)
# Out:
# Call:
# lm(formula = y ~ poly(x, 4))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.28588 -0.06628  0.01059  0.06963  0.21545
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.01520    0.01483   1.025  0.30960
# poly(x, 4)1  4.40940    0.11774  37.451  < 2e-16 ***
# poly(x, 4)2  0.31421    0.11774   2.669  0.00986 **
# poly(x, 4)3 -3.41268    0.11774 -28.985  < 2e-16 ***
# poly(x, 4)4 -0.11650    0.11774  -0.989  0.32653
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1177 on 58 degrees of freedom
# Multiple R-squared:  0.9749,	Adjusted R-squared:  0.9731
# F-statistic: 562.7 on 4 and 58 DF,  p-value: < 2.2e-16
# plot without title

# %%
set.seed(1)
x <- seq(-pi,pi,by=.1)
y <- sin(x) + rnorm(length(x),sd=0)
plot(x, y)
fit <- lm(y ~ poly(x,4))
lines(x,fit$fit, col="blue")
summary(fit)
# Out:
# Call:
# lm(formula = y ~ poly(x, 4))
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.161379 -0.060366 -0.000907  0.060086  0.165169
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.000111   0.008743   0.013  0.98991
# poly(x, 4)1  4.351161   0.069393  62.703  < 2e-16 ***
# poly(x, 4)2  0.224540   0.069393   3.236  0.00201 **
# poly(x, 4)3 -3.485629   0.069393 -50.230  < 2e-16 ***
# poly(x, 4)4 -0.064433   0.069393  -0.929  0.35699
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.06939 on 58 degrees of freedom
# Multiple R-squared:  0.9911,	Adjusted R-squared:  0.9905
# F-statistic:  1617 on 4 and 58 DF,  p-value: < 2.2e-16
# plot without title

# %% [markdown]
# ## Using Jitter

# %%
set.seed(1)
n <- 45
xlim <- c((-pi+1.3),(pi-.3))
x <- seq(xlim[1],xlim[2], length.out=n)
y <- jitter(sin(x), amount=.4)
y.known <- sin(x)
plot(x,y)
lines(x,y.known)
# Out:
# plot without title
